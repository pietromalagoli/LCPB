# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, AveragePooling1D
# Out:
# 2024-03-04 10:56:01.200568: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-04 10:56:01.922713: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-04 10:56:03.361369: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Read data

# %%
def Show_data(x,L,s="data",T=3):
    c=("k","r","b")
    for i in range(T):
        j=i*3*L
        plt.plot(np.arange(j,j+L),x[i*3],c=c[0])
        plt.plot(np.arange(j+L,j+2*L),x[i*3+1],c=c[1])
        plt.plot(np.arange(j+2*L,j+3*L),x[i*3+2],c=c[2])
    plt.title(s)
    plt.xlabel("time")
    plt.show()
    
str0="ts_L80_N4000.dat"
fnamex='x_'+str0
fnamey='y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"part of the original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  4000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
# bring each sample to zero average
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x / x.std()
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)  ## THIS IS ASKED BY KERAS TO BE LIKE THIS, EVEN IF YOU HAVE A 1 LAYER
# Out:
# N_train= 3200   N_val= 800   L= 80   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

NCONV=1

def build_model(NCONV=1, NF=5,KS=6, NF2=5,KS2=4, lamb=0):
    """
    filter = kernel
    NCONV=index of the CNN architecture
    NF=nr of filters in the 1st layer
    KS=kernel size in the 1st layer
    NF2=nr of filters in the 2nd layer
    KS2=kernel size in the 2nd layer
    lamb=not the animal, but lambda, the regularization parameter
    """
    # regularizers, l2=Ridge, l1=LASSO
    reg = keras.regularizers.l2(lamb)
    model = Sequential()

    # Version with last layer Dense
    if NCONV==1:
        model.add(Conv1D(filters=NF,   ## FIRST CONVOLUTION
                         kernel_size=KS,
                         kernel_regularizer=reg,
                         activation='relu', 
                         input_shape=input_shape))
        model.add(MaxPooling1D(3)) ## POOLING
        #model.add(AveragePooling1D(3))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu')) ## SECOND CONVOLUTION     
        model.add(Flatten()) ## FLATTENING
        model.add(Dense(12, activation='relu')) ## THE OUTPUT TO THIS POINT IS FED TO A 1-LAYER DENSE NEURAL NETWORK    
        model.add(Dropout(0.2))

    # Version with last layer GlobalMaxPooling, one more intermediate conv1D, and no intermediate pooling
    if NCONV==2:
        model.add(Conv1D(filters=NF, 
                         kernel_size=KS,
                         kernel_regularizer=reg,
                         activation='relu', 
                         input_shape=input_shape))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu'))
        model.add(Conv1D(filters=NF2, kernel_size=KS2,activation='relu')) ## THIRD CONVOLUTION
        model.add(tf.keras.layers.GlobalMaxPooling1D()) ## GLOBAL MAX POOLING MEANS THAT YOU TAKE THE MAXIMUM CONVOLUTION AND YOU DO POOLING ON THAT
        model.add(Flatten())
        
    # Last layer, with n_class units  
    model.add(Dense(n_class, activation='softmax')) # softmax !
    
    # optimizers
    # .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
    # .RMSprop()
    # .Nadam()
    # Define the optimizer learning rate as a hyperparameter.
    opt = keras.optimizers.Adam()  ## I SET THE OPTIMIZER TO BE ADAM
    
    # compile the model
    # categorical_crossentropy, 3 output nodes
    model.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])  ## SET LOSS FUNCTION TO BE CATEGORICAL CROSS ENTROPY
    return model

model=build_model(NCONV=NCONV,KS=11)


print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])

print(model.layers)
# Out:
# ----- Model 1 -----
# /home/pietromalagoli/anaconda3/envs/lcpB/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 2024-03-04 11:03:21.995270: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:03:21.995835: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 70, 5)          │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 23, 5)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 20, 5)          │           105 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │         1,212 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,416 (5.53 KB)
#  Trainable params: 1,416 (5.53 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# [<Conv1D name=conv1d, built=True>, <MaxPooling1D name=max_pooling1d, built=True>, <Conv1D name=conv1d_1, built=True>, <Flatten name=flatten, built=True>, <Dense name=dense, built=True>, <Dropout name=dropout, built=True>, <Dense name=dense_1, built=True>]

# %%
def Show_weights(model,l=0,label="model"):  ## JUST TO VISUALIZE THE WEIGHTS AND BIASES
    c=['r','y','c','b','m','k',"gray","cyan","g"]
    m=['o','s','D','<','>','^','+','x','d',"*"]
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i%len(c)],marker=m[i%len(m)],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i%len(c)],marker=m[i%len(m)],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 300

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,  ## TRAINING, THROUGH BATCHES
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True) 
print("end of fit")
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/300
# 16/16 - 2s - 99ms/step - accuracy: 0.3331 - loss: 1.1057 - val_accuracy: 0.3325 - val_loss: 1.1020
# Epoch 2/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3487 - loss: 1.0986 - val_accuracy: 0.3300 - val_loss: 1.1013
# Epoch 3/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3481 - loss: 1.0977 - val_accuracy: 0.3350 - val_loss: 1.1000
# Epoch 4/300
# 16/16 - 0s - 9ms/step - accuracy: 0.3641 - loss: 1.0961 - val_accuracy: 0.3325 - val_loss: 1.1001
# Epoch 5/300
# 16/16 - 0s - 9ms/step - accuracy: 0.3628 - loss: 1.0940 - val_accuracy: 0.3325 - val_loss: 1.0989
# Epoch 6/300
# 16/16 - 0s - 9ms/step - accuracy: 0.3706 - loss: 1.0930 - val_accuracy: 0.3375 - val_loss: 1.0984
# Epoch 7/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3781 - loss: 1.0917 - val_accuracy: 0.3388 - val_loss: 1.0978
# Epoch 8/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3669 - loss: 1.0910 - val_accuracy: 0.3475 - val_loss: 1.0971
# Epoch 9/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3741 - loss: 1.0886 - val_accuracy: 0.3550 - val_loss: 1.0962
# Epoch 10/300
# 16/16 - 0s - 8ms/step - accuracy: 0.3853 - loss: 1.0861 - val_accuracy: 0.3562 - val_loss: 1.0957
# Epoch 11/300
# 16/16 - 0s - 9ms/step - accuracy: 0.3913 - loss: 1.0835 - val_accuracy: 0.3587 - val_loss: 1.0946
# Epoch 12/300
# 16/16 - 0s - 9ms/step - accuracy: 0.3900 - loss: 1.0813 - val_accuracy: 0.3587 - val_loss: 1.0938
# Epoch 13/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4034 - loss: 1.0787 - val_accuracy: 0.3638 - val_loss: 1.0923
# Epoch 14/300
# 16/16 - 0s - 9ms/step - accuracy: 0.4072 - loss: 1.0750 - val_accuracy: 0.3625 - val_loss: 1.0905
# Epoch 15/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4066 - loss: 1.0738 - val_accuracy: 0.3750 - val_loss: 1.0881
# Epoch 16/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4263 - loss: 1.0667 - val_accuracy: 0.3700 - val_loss: 1.0866
# Epoch 17/300
# 16/16 - 0s - 9ms/step - accuracy: 0.4247 - loss: 1.0654 - val_accuracy: 0.3938 - val_loss: 1.0817
# Epoch 18/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4225 - loss: 1.0580 - val_accuracy: 0.3750 - val_loss: 1.0783
# Epoch 19/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4522 - loss: 1.0526 - val_accuracy: 0.3988 - val_loss: 1.0734
# Epoch 20/300
# 16/16 - 0s - 7ms/step - accuracy: 0.4478 - loss: 1.0513 - val_accuracy: 0.4075 - val_loss: 1.0673
# Epoch 21/300
# 16/16 - 0s - 8ms/step - accuracy: 0.4472 - loss: 1.0443 - val_accuracy: 0.4200 - val_loss: 1.0610
# Epoch 22/300
# 16/16 - 0s - 7ms/step - accuracy: 0.4703 - loss: 1.0379 - val_accuracy: 0.4225 - val_loss: 1.0556
# Epoch 23/300
# 16/16 - 0s - 7ms/step - accuracy: 0.4803 - loss: 1.0287 - val_accuracy: 0.4313 - val_loss: 1.0484
# Epoch 24/300
# 16/16 - 0s - 7ms/step - accuracy: 0.4875 - loss: 1.0195 - val_accuracy: 0.4313 - val_loss: 1.0417
# Epoch 25/300
# 16/16 - 0s - 7ms/step - accuracy: 0.4938 - loss: 1.0178 - val_accuracy: 0.4387 - val_loss: 1.0333
# Epoch 26/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5041 - loss: 1.0051 - val_accuracy: 0.4437 - val_loss: 1.0260
# Epoch 27/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5119 - loss: 0.9984 - val_accuracy: 0.4512 - val_loss: 1.0165
# Epoch 28/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5341 - loss: 0.9860 - val_accuracy: 0.4625 - val_loss: 1.0076
# Epoch 29/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5219 - loss: 0.9783 - val_accuracy: 0.4638 - val_loss: 0.9969
# Epoch 30/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5378 - loss: 0.9662 - val_accuracy: 0.4750 - val_loss: 0.9861
# Epoch 31/300
# 16/16 - 0s - 9ms/step - accuracy: 0.5400 - loss: 0.9559 - val_accuracy: 0.4787 - val_loss: 0.9749
# Epoch 32/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5481 - loss: 0.9458 - val_accuracy: 0.4888 - val_loss: 0.9669
# Epoch 33/300
# 16/16 - 0s - 9ms/step - accuracy: 0.5625 - loss: 0.9325 - val_accuracy: 0.4837 - val_loss: 0.9575
# Epoch 34/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5628 - loss: 0.9254 - val_accuracy: 0.4825 - val_loss: 0.9557
# Epoch 35/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5606 - loss: 0.9194 - val_accuracy: 0.4938 - val_loss: 0.9456
# Epoch 36/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5622 - loss: 0.9171 - val_accuracy: 0.4950 - val_loss: 0.9398
# Epoch 37/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5581 - loss: 0.9073 - val_accuracy: 0.5100 - val_loss: 0.9298
# Epoch 38/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5641 - loss: 0.9069 - val_accuracy: 0.5213 - val_loss: 0.9156
# Epoch 39/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5700 - loss: 0.8903 - val_accuracy: 0.5312 - val_loss: 0.9047
# Epoch 40/300
# 16/16 - 0s - 10ms/step - accuracy: 0.5691 - loss: 0.8881 - val_accuracy: 0.5400 - val_loss: 0.9003
# Epoch 41/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5875 - loss: 0.8771 - val_accuracy: 0.5412 - val_loss: 0.8983
# Epoch 42/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5800 - loss: 0.8780 - val_accuracy: 0.5288 - val_loss: 0.8958
# Epoch 43/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5928 - loss: 0.8706 - val_accuracy: 0.5275 - val_loss: 0.8899
# Epoch 44/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5913 - loss: 0.8719 - val_accuracy: 0.5425 - val_loss: 0.8819
# Epoch 45/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5956 - loss: 0.8624 - val_accuracy: 0.5425 - val_loss: 0.8766
# Epoch 46/300
# 16/16 - 0s - 7ms/step - accuracy: 0.5919 - loss: 0.8570 - val_accuracy: 0.5475 - val_loss: 0.8711
# Epoch 47/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6075 - loss: 0.8433 - val_accuracy: 0.5562 - val_loss: 0.8691
# Epoch 48/300
# 16/16 - 0s - 8ms/step - accuracy: 0.5981 - loss: 0.8478 - val_accuracy: 0.5600 - val_loss: 0.8615
# Epoch 49/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6016 - loss: 0.8399 - val_accuracy: 0.5525 - val_loss: 0.8649
# Epoch 50/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6047 - loss: 0.8437 - val_accuracy: 0.5562 - val_loss: 0.8607
# Epoch 51/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6025 - loss: 0.8351 - val_accuracy: 0.5700 - val_loss: 0.8536
# Epoch 52/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6087 - loss: 0.8376 - val_accuracy: 0.5700 - val_loss: 0.8535
# Epoch 53/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6066 - loss: 0.8367 - val_accuracy: 0.5825 - val_loss: 0.8527
# Epoch 54/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6175 - loss: 0.8312 - val_accuracy: 0.5813 - val_loss: 0.8483
# Epoch 55/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6150 - loss: 0.8240 - val_accuracy: 0.5850 - val_loss: 0.8458
# Epoch 56/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6109 - loss: 0.8300 - val_accuracy: 0.5900 - val_loss: 0.8433
# Epoch 57/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6209 - loss: 0.8154 - val_accuracy: 0.5913 - val_loss: 0.8394
# Epoch 58/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6288 - loss: 0.8203 - val_accuracy: 0.5975 - val_loss: 0.8385
# Epoch 59/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6259 - loss: 0.8103 - val_accuracy: 0.5975 - val_loss: 0.8367
# Epoch 60/300
# 16/16 - 0s - 9ms/step - accuracy: 0.6344 - loss: 0.8112 - val_accuracy: 0.5950 - val_loss: 0.8349
# Epoch 61/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6144 - loss: 0.8152 - val_accuracy: 0.6037 - val_loss: 0.8322
# Epoch 62/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6291 - loss: 0.8067 - val_accuracy: 0.6050 - val_loss: 0.8291
# Epoch 63/300
# 16/16 - 0s - 9ms/step - accuracy: 0.6331 - loss: 0.8028 - val_accuracy: 0.6162 - val_loss: 0.8269
# Epoch 64/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6353 - loss: 0.8024 - val_accuracy: 0.6162 - val_loss: 0.8295
# Epoch 65/300
# 16/16 - 0s - 10ms/step - accuracy: 0.6284 - loss: 0.7975 - val_accuracy: 0.6237 - val_loss: 0.8177
# Epoch 66/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6472 - loss: 0.7876 - val_accuracy: 0.6237 - val_loss: 0.8209
# Epoch 67/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6378 - loss: 0.7922 - val_accuracy: 0.6325 - val_loss: 0.8213
# Epoch 68/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6369 - loss: 0.7952 - val_accuracy: 0.6325 - val_loss: 0.8169
# Epoch 69/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6419 - loss: 0.7913 - val_accuracy: 0.6350 - val_loss: 0.8150
# Epoch 70/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6450 - loss: 0.7836 - val_accuracy: 0.6338 - val_loss: 0.8147
# Epoch 71/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6456 - loss: 0.7835 - val_accuracy: 0.6338 - val_loss: 0.8083
# Epoch 72/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6463 - loss: 0.7804 - val_accuracy: 0.6325 - val_loss: 0.8081
# Epoch 73/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6406 - loss: 0.7775 - val_accuracy: 0.6350 - val_loss: 0.8057
# Epoch 74/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6544 - loss: 0.7779 - val_accuracy: 0.6413 - val_loss: 0.8036
# Epoch 75/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6550 - loss: 0.7711 - val_accuracy: 0.6438 - val_loss: 0.8053
# Epoch 76/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6481 - loss: 0.7816 - val_accuracy: 0.6413 - val_loss: 0.7971
# Epoch 77/300
# 16/16 - 0s - 9ms/step - accuracy: 0.6559 - loss: 0.7690 - val_accuracy: 0.6500 - val_loss: 0.7956
# Epoch 78/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6612 - loss: 0.7668 - val_accuracy: 0.6500 - val_loss: 0.7944
# Epoch 79/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6603 - loss: 0.7647 - val_accuracy: 0.6463 - val_loss: 0.7934
# Epoch 80/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6559 - loss: 0.7589 - val_accuracy: 0.6525 - val_loss: 0.7905
# Epoch 81/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6569 - loss: 0.7631 - val_accuracy: 0.6612 - val_loss: 0.7909
# Epoch 82/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6647 - loss: 0.7667 - val_accuracy: 0.6637 - val_loss: 0.7834
# Epoch 83/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6650 - loss: 0.7593 - val_accuracy: 0.6587 - val_loss: 0.7851
# Epoch 84/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6675 - loss: 0.7535 - val_accuracy: 0.6625 - val_loss: 0.7850
# Epoch 85/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6644 - loss: 0.7495 - val_accuracy: 0.6575 - val_loss: 0.7846
# Epoch 86/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6731 - loss: 0.7540 - val_accuracy: 0.6600 - val_loss: 0.7820
# Epoch 87/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6725 - loss: 0.7480 - val_accuracy: 0.6625 - val_loss: 0.7762
# Epoch 88/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6703 - loss: 0.7450 - val_accuracy: 0.6575 - val_loss: 0.7814
# Epoch 89/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6719 - loss: 0.7467 - val_accuracy: 0.6587 - val_loss: 0.7762
# Epoch 90/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6741 - loss: 0.7446 - val_accuracy: 0.6662 - val_loss: 0.7751
# Epoch 91/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6772 - loss: 0.7420 - val_accuracy: 0.6675 - val_loss: 0.7738
# Epoch 92/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6806 - loss: 0.7340 - val_accuracy: 0.6675 - val_loss: 0.7730
# Epoch 93/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6784 - loss: 0.7376 - val_accuracy: 0.6712 - val_loss: 0.7724
# Epoch 94/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6766 - loss: 0.7417 - val_accuracy: 0.6587 - val_loss: 0.7757
# Epoch 95/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6844 - loss: 0.7368 - val_accuracy: 0.6700 - val_loss: 0.7675
# Epoch 96/300
# 16/16 - 0s - 9ms/step - accuracy: 0.6812 - loss: 0.7376 - val_accuracy: 0.6637 - val_loss: 0.7688
# Epoch 97/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6859 - loss: 0.7303 - val_accuracy: 0.6675 - val_loss: 0.7668
# Epoch 98/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6841 - loss: 0.7307 - val_accuracy: 0.6675 - val_loss: 0.7684
# Epoch 99/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6775 - loss: 0.7330 - val_accuracy: 0.6737 - val_loss: 0.7670
# Epoch 100/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6822 - loss: 0.7247 - val_accuracy: 0.6712 - val_loss: 0.7613
# Epoch 101/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6847 - loss: 0.7193 - val_accuracy: 0.6712 - val_loss: 0.7639
# Epoch 102/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6837 - loss: 0.7268 - val_accuracy: 0.6700 - val_loss: 0.7588
# Epoch 103/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6847 - loss: 0.7293 - val_accuracy: 0.6700 - val_loss: 0.7628
# Epoch 104/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6844 - loss: 0.7240 - val_accuracy: 0.6725 - val_loss: 0.7580
# Epoch 105/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6881 - loss: 0.7216 - val_accuracy: 0.6712 - val_loss: 0.7578
# Epoch 106/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6884 - loss: 0.7196 - val_accuracy: 0.6675 - val_loss: 0.7577
# Epoch 107/300
# 16/16 - 0s - 6ms/step - accuracy: 0.6866 - loss: 0.7206 - val_accuracy: 0.6687 - val_loss: 0.7583
# Epoch 108/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6941 - loss: 0.7131 - val_accuracy: 0.6675 - val_loss: 0.7563
# Epoch 109/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6869 - loss: 0.7180 - val_accuracy: 0.6675 - val_loss: 0.7543
# Epoch 110/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6978 - loss: 0.7130 - val_accuracy: 0.6675 - val_loss: 0.7525
# Epoch 111/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6969 - loss: 0.7065 - val_accuracy: 0.6687 - val_loss: 0.7520
# Epoch 112/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6944 - loss: 0.7075 - val_accuracy: 0.6662 - val_loss: 0.7541
# Epoch 113/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6959 - loss: 0.7079 - val_accuracy: 0.6675 - val_loss: 0.7526
# Epoch 114/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6925 - loss: 0.7072 - val_accuracy: 0.6812 - val_loss: 0.7469
# Epoch 115/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6997 - loss: 0.7041 - val_accuracy: 0.6662 - val_loss: 0.7498
# Epoch 116/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6944 - loss: 0.7082 - val_accuracy: 0.6675 - val_loss: 0.7484
# Epoch 117/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6988 - loss: 0.7055 - val_accuracy: 0.6712 - val_loss: 0.7498
# Epoch 118/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6919 - loss: 0.7093 - val_accuracy: 0.6712 - val_loss: 0.7463
# Epoch 119/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6944 - loss: 0.7077 - val_accuracy: 0.6725 - val_loss: 0.7476
# Epoch 120/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7022 - loss: 0.7010 - val_accuracy: 0.6712 - val_loss: 0.7444
# Epoch 121/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7091 - loss: 0.6973 - val_accuracy: 0.6750 - val_loss: 0.7437
# Epoch 122/300
# 16/16 - 0s - 8ms/step - accuracy: 0.6981 - loss: 0.7032 - val_accuracy: 0.6750 - val_loss: 0.7426
# Epoch 123/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7016 - loss: 0.6935 - val_accuracy: 0.6750 - val_loss: 0.7465
# Epoch 124/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7028 - loss: 0.6957 - val_accuracy: 0.6750 - val_loss: 0.7472
# Epoch 125/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6966 - loss: 0.7015 - val_accuracy: 0.6762 - val_loss: 0.7439
# Epoch 126/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7028 - loss: 0.6930 - val_accuracy: 0.6787 - val_loss: 0.7410
# Epoch 127/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7059 - loss: 0.6927 - val_accuracy: 0.6750 - val_loss: 0.7445
# Epoch 128/300
# 16/16 - 0s - 7ms/step - accuracy: 0.6997 - loss: 0.7008 - val_accuracy: 0.6800 - val_loss: 0.7404
# Epoch 129/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7169 - loss: 0.6820 - val_accuracy: 0.6800 - val_loss: 0.7420
# Epoch 130/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7100 - loss: 0.6908 - val_accuracy: 0.6762 - val_loss: 0.7410
# Epoch 131/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7088 - loss: 0.6907 - val_accuracy: 0.6787 - val_loss: 0.7374
# Epoch 132/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7078 - loss: 0.6892 - val_accuracy: 0.6737 - val_loss: 0.7400
# Epoch 133/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7000 - loss: 0.6938 - val_accuracy: 0.6762 - val_loss: 0.7377
# Epoch 134/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7122 - loss: 0.6842 - val_accuracy: 0.6750 - val_loss: 0.7372
# Epoch 135/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7188 - loss: 0.6811 - val_accuracy: 0.6787 - val_loss: 0.7332
# Epoch 136/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7128 - loss: 0.6846 - val_accuracy: 0.6775 - val_loss: 0.7336
# Epoch 137/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7081 - loss: 0.6864 - val_accuracy: 0.6850 - val_loss: 0.7343
# Epoch 138/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7106 - loss: 0.6859 - val_accuracy: 0.6862 - val_loss: 0.7334
# Epoch 139/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7109 - loss: 0.6761 - val_accuracy: 0.6800 - val_loss: 0.7333
# Epoch 140/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7128 - loss: 0.6853 - val_accuracy: 0.6875 - val_loss: 0.7325
# Epoch 141/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7228 - loss: 0.6703 - val_accuracy: 0.6850 - val_loss: 0.7327
# Epoch 142/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7134 - loss: 0.6815 - val_accuracy: 0.6775 - val_loss: 0.7324
# Epoch 143/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7138 - loss: 0.6803 - val_accuracy: 0.6787 - val_loss: 0.7332
# Epoch 144/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7169 - loss: 0.6814 - val_accuracy: 0.6875 - val_loss: 0.7300
# Epoch 145/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7200 - loss: 0.6833 - val_accuracy: 0.6850 - val_loss: 0.7296
# Epoch 146/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7241 - loss: 0.6720 - val_accuracy: 0.6900 - val_loss: 0.7308
# Epoch 147/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7125 - loss: 0.6810 - val_accuracy: 0.6875 - val_loss: 0.7306
# Epoch 148/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7194 - loss: 0.6760 - val_accuracy: 0.6888 - val_loss: 0.7321
# Epoch 149/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7188 - loss: 0.6778 - val_accuracy: 0.6825 - val_loss: 0.7301
# Epoch 150/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7206 - loss: 0.6753 - val_accuracy: 0.6837 - val_loss: 0.7295
# Epoch 151/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7188 - loss: 0.6720 - val_accuracy: 0.6850 - val_loss: 0.7298
# Epoch 152/300
# 16/16 - 0s - 6ms/step - accuracy: 0.7219 - loss: 0.6664 - val_accuracy: 0.6900 - val_loss: 0.7283
# Epoch 153/300
# 16/16 - 0s - 6ms/step - accuracy: 0.7191 - loss: 0.6671 - val_accuracy: 0.6862 - val_loss: 0.7312
# Epoch 154/300
# 16/16 - 0s - 6ms/step - accuracy: 0.7184 - loss: 0.6658 - val_accuracy: 0.6875 - val_loss: 0.7281
# Epoch 155/300
# 16/16 - 0s - 6ms/step - accuracy: 0.7178 - loss: 0.6722 - val_accuracy: 0.6850 - val_loss: 0.7254
# Epoch 156/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7169 - loss: 0.6687 - val_accuracy: 0.6862 - val_loss: 0.7276
# Epoch 157/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7278 - loss: 0.6649 - val_accuracy: 0.6812 - val_loss: 0.7274
# Epoch 158/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7259 - loss: 0.6585 - val_accuracy: 0.6850 - val_loss: 0.7294
# Epoch 159/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7247 - loss: 0.6649 - val_accuracy: 0.6875 - val_loss: 0.7268
# Epoch 160/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7272 - loss: 0.6640 - val_accuracy: 0.6787 - val_loss: 0.7255
# Epoch 161/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7266 - loss: 0.6573 - val_accuracy: 0.6888 - val_loss: 0.7281
# Epoch 162/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7197 - loss: 0.6620 - val_accuracy: 0.6862 - val_loss: 0.7270
# Epoch 163/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7203 - loss: 0.6664 - val_accuracy: 0.6837 - val_loss: 0.7245
# Epoch 164/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7316 - loss: 0.6490 - val_accuracy: 0.6825 - val_loss: 0.7241
# Epoch 165/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7269 - loss: 0.6577 - val_accuracy: 0.6837 - val_loss: 0.7294
# Epoch 166/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7275 - loss: 0.6578 - val_accuracy: 0.6837 - val_loss: 0.7275
# Epoch 167/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7316 - loss: 0.6552 - val_accuracy: 0.6812 - val_loss: 0.7259
# Epoch 168/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7312 - loss: 0.6505 - val_accuracy: 0.6850 - val_loss: 0.7265
# Epoch 169/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7256 - loss: 0.6596 - val_accuracy: 0.6787 - val_loss: 0.7226
# Epoch 170/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7331 - loss: 0.6524 - val_accuracy: 0.6862 - val_loss: 0.7230
# Epoch 171/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7188 - loss: 0.6655 - val_accuracy: 0.6787 - val_loss: 0.7237
# Epoch 172/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7272 - loss: 0.6558 - val_accuracy: 0.6825 - val_loss: 0.7232
# Epoch 173/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7259 - loss: 0.6531 - val_accuracy: 0.6775 - val_loss: 0.7242
# Epoch 174/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7300 - loss: 0.6488 - val_accuracy: 0.6862 - val_loss: 0.7227
# Epoch 175/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7281 - loss: 0.6529 - val_accuracy: 0.6837 - val_loss: 0.7231
# Epoch 176/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7291 - loss: 0.6502 - val_accuracy: 0.6825 - val_loss: 0.7246
# Epoch 177/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7291 - loss: 0.6459 - val_accuracy: 0.6837 - val_loss: 0.7252
# Epoch 178/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7188 - loss: 0.6566 - val_accuracy: 0.6775 - val_loss: 0.7280
# Epoch 179/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7359 - loss: 0.6428 - val_accuracy: 0.6837 - val_loss: 0.7229
# Epoch 180/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7331 - loss: 0.6501 - val_accuracy: 0.6825 - val_loss: 0.7230
# Epoch 181/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7350 - loss: 0.6415 - val_accuracy: 0.6862 - val_loss: 0.7262
# Epoch 182/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7337 - loss: 0.6367 - val_accuracy: 0.6800 - val_loss: 0.7232
# Epoch 183/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7300 - loss: 0.6400 - val_accuracy: 0.6837 - val_loss: 0.7232
# Epoch 184/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7262 - loss: 0.6587 - val_accuracy: 0.6775 - val_loss: 0.7235
# Epoch 185/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7247 - loss: 0.6498 - val_accuracy: 0.6812 - val_loss: 0.7219
# Epoch 186/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7344 - loss: 0.6449 - val_accuracy: 0.6862 - val_loss: 0.7232
# Epoch 187/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7341 - loss: 0.6545 - val_accuracy: 0.6812 - val_loss: 0.7214
# Epoch 188/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7384 - loss: 0.6414 - val_accuracy: 0.6812 - val_loss: 0.7234
# Epoch 189/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7303 - loss: 0.6388 - val_accuracy: 0.6938 - val_loss: 0.7194
# Epoch 190/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7350 - loss: 0.6488 - val_accuracy: 0.6875 - val_loss: 0.7221
# Epoch 191/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7387 - loss: 0.6392 - val_accuracy: 0.6850 - val_loss: 0.7199
# Epoch 192/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7272 - loss: 0.6536 - val_accuracy: 0.6850 - val_loss: 0.7219
# Epoch 193/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7381 - loss: 0.6437 - val_accuracy: 0.6825 - val_loss: 0.7218
# Epoch 194/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7400 - loss: 0.6289 - val_accuracy: 0.6913 - val_loss: 0.7204
# Epoch 195/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7328 - loss: 0.6419 - val_accuracy: 0.6850 - val_loss: 0.7250
# Epoch 196/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7397 - loss: 0.6356 - val_accuracy: 0.6900 - val_loss: 0.7207
# Epoch 197/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7406 - loss: 0.6342 - val_accuracy: 0.6888 - val_loss: 0.7240
# Epoch 198/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7353 - loss: 0.6404 - val_accuracy: 0.6913 - val_loss: 0.7214
# Epoch 199/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7400 - loss: 0.6411 - val_accuracy: 0.6900 - val_loss: 0.7221
# Epoch 200/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7269 - loss: 0.6356 - val_accuracy: 0.6875 - val_loss: 0.7208
# Epoch 201/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7356 - loss: 0.6354 - val_accuracy: 0.6862 - val_loss: 0.7209
# Epoch 202/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7337 - loss: 0.6427 - val_accuracy: 0.6875 - val_loss: 0.7219
# Epoch 203/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7369 - loss: 0.6423 - val_accuracy: 0.6888 - val_loss: 0.7227
# Epoch 204/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7397 - loss: 0.6389 - val_accuracy: 0.6913 - val_loss: 0.7207
# Epoch 205/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7447 - loss: 0.6250 - val_accuracy: 0.6913 - val_loss: 0.7220
# Epoch 206/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7344 - loss: 0.6325 - val_accuracy: 0.6913 - val_loss: 0.7193
# Epoch 207/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7319 - loss: 0.6319 - val_accuracy: 0.6812 - val_loss: 0.7217
# Epoch 208/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7434 - loss: 0.6237 - val_accuracy: 0.6875 - val_loss: 0.7209
# Epoch 209/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7344 - loss: 0.6298 - val_accuracy: 0.6888 - val_loss: 0.7218
# Epoch 210/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7344 - loss: 0.6313 - val_accuracy: 0.6913 - val_loss: 0.7194
# Epoch 211/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7425 - loss: 0.6278 - val_accuracy: 0.6900 - val_loss: 0.7186
# Epoch 212/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7412 - loss: 0.6259 - val_accuracy: 0.6900 - val_loss: 0.7220
# Epoch 213/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7409 - loss: 0.6298 - val_accuracy: 0.6913 - val_loss: 0.7227
# Epoch 214/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7397 - loss: 0.6316 - val_accuracy: 0.6938 - val_loss: 0.7257
# Epoch 215/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7419 - loss: 0.6325 - val_accuracy: 0.6925 - val_loss: 0.7183
# Epoch 216/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7359 - loss: 0.6325 - val_accuracy: 0.6913 - val_loss: 0.7203
# Epoch 217/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7403 - loss: 0.6290 - val_accuracy: 0.6938 - val_loss: 0.7180
# Epoch 218/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7525 - loss: 0.6127 - val_accuracy: 0.6925 - val_loss: 0.7234
# Epoch 219/300
# 16/16 - 0s - 6ms/step - accuracy: 0.7391 - loss: 0.6275 - val_accuracy: 0.6975 - val_loss: 0.7229
# Epoch 220/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7484 - loss: 0.6206 - val_accuracy: 0.6950 - val_loss: 0.7197
# Epoch 221/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7484 - loss: 0.6263 - val_accuracy: 0.6963 - val_loss: 0.7182
# Epoch 222/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7344 - loss: 0.6286 - val_accuracy: 0.6888 - val_loss: 0.7213
# Epoch 223/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7387 - loss: 0.6366 - val_accuracy: 0.6975 - val_loss: 0.7200
# Epoch 224/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7494 - loss: 0.6233 - val_accuracy: 0.7000 - val_loss: 0.7137
# Epoch 225/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7494 - loss: 0.6200 - val_accuracy: 0.6988 - val_loss: 0.7216
# Epoch 226/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7462 - loss: 0.6244 - val_accuracy: 0.6988 - val_loss: 0.7140
# Epoch 227/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7406 - loss: 0.6306 - val_accuracy: 0.7000 - val_loss: 0.7169
# Epoch 228/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7406 - loss: 0.6239 - val_accuracy: 0.7038 - val_loss: 0.7138
# Epoch 229/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7506 - loss: 0.6156 - val_accuracy: 0.6938 - val_loss: 0.7179
# Epoch 230/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7419 - loss: 0.6317 - val_accuracy: 0.7000 - val_loss: 0.7145
# Epoch 231/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7447 - loss: 0.6242 - val_accuracy: 0.6938 - val_loss: 0.7172
# Epoch 232/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7428 - loss: 0.6131 - val_accuracy: 0.7000 - val_loss: 0.7214
# Epoch 233/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7409 - loss: 0.6170 - val_accuracy: 0.6888 - val_loss: 0.7200
# Epoch 234/300
# 16/16 - 0s - 11ms/step - accuracy: 0.7425 - loss: 0.6152 - val_accuracy: 0.7013 - val_loss: 0.7196
# Epoch 235/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7387 - loss: 0.6273 - val_accuracy: 0.6950 - val_loss: 0.7203
# Epoch 236/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7475 - loss: 0.6183 - val_accuracy: 0.7013 - val_loss: 0.7202
# Epoch 237/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7506 - loss: 0.6188 - val_accuracy: 0.7025 - val_loss: 0.7203
# Epoch 238/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7416 - loss: 0.6247 - val_accuracy: 0.7013 - val_loss: 0.7176
# Epoch 239/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7469 - loss: 0.6181 - val_accuracy: 0.7025 - val_loss: 0.7208
# Epoch 240/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7503 - loss: 0.6245 - val_accuracy: 0.6963 - val_loss: 0.7145
# Epoch 241/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7503 - loss: 0.6108 - val_accuracy: 0.6963 - val_loss: 0.7171
# Epoch 242/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7472 - loss: 0.6155 - val_accuracy: 0.6988 - val_loss: 0.7182
# Epoch 243/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7434 - loss: 0.6193 - val_accuracy: 0.6950 - val_loss: 0.7181
# Epoch 244/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7459 - loss: 0.6148 - val_accuracy: 0.6950 - val_loss: 0.7159
# Epoch 245/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7416 - loss: 0.6164 - val_accuracy: 0.6975 - val_loss: 0.7186
# Epoch 246/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7441 - loss: 0.6103 - val_accuracy: 0.6938 - val_loss: 0.7179
# Epoch 247/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7478 - loss: 0.6165 - val_accuracy: 0.6975 - val_loss: 0.7165
# Epoch 248/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7466 - loss: 0.6153 - val_accuracy: 0.7000 - val_loss: 0.7184
# Epoch 249/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7538 - loss: 0.5996 - val_accuracy: 0.6950 - val_loss: 0.7204
# Epoch 250/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7309 - loss: 0.6250 - val_accuracy: 0.6975 - val_loss: 0.7208
# Epoch 251/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7453 - loss: 0.6104 - val_accuracy: 0.6963 - val_loss: 0.7160
# Epoch 252/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7519 - loss: 0.6086 - val_accuracy: 0.7000 - val_loss: 0.7200
# Epoch 253/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7541 - loss: 0.6093 - val_accuracy: 0.7000 - val_loss: 0.7169
# Epoch 254/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7428 - loss: 0.6142 - val_accuracy: 0.6988 - val_loss: 0.7194
# Epoch 255/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7509 - loss: 0.6066 - val_accuracy: 0.6975 - val_loss: 0.7154
# Epoch 256/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7534 - loss: 0.6032 - val_accuracy: 0.6950 - val_loss: 0.7178
# Epoch 257/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7459 - loss: 0.6124 - val_accuracy: 0.7000 - val_loss: 0.7175
# Epoch 258/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7606 - loss: 0.6037 - val_accuracy: 0.7025 - val_loss: 0.7145
# Epoch 259/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7469 - loss: 0.6125 - val_accuracy: 0.6963 - val_loss: 0.7205
# Epoch 260/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7509 - loss: 0.6165 - val_accuracy: 0.7013 - val_loss: 0.7164
# Epoch 261/300
# 16/16 - 0s - 10ms/step - accuracy: 0.7525 - loss: 0.6022 - val_accuracy: 0.6938 - val_loss: 0.7215
# Epoch 262/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7428 - loss: 0.6110 - val_accuracy: 0.6975 - val_loss: 0.7200
# Epoch 263/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7484 - loss: 0.6071 - val_accuracy: 0.6913 - val_loss: 0.7196
# Epoch 264/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7459 - loss: 0.6083 - val_accuracy: 0.6950 - val_loss: 0.7158
# Epoch 265/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7534 - loss: 0.6040 - val_accuracy: 0.6950 - val_loss: 0.7233
# Epoch 266/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7500 - loss: 0.6087 - val_accuracy: 0.6975 - val_loss: 0.7202
# Epoch 267/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7491 - loss: 0.6049 - val_accuracy: 0.6938 - val_loss: 0.7240
# Epoch 268/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7506 - loss: 0.6097 - val_accuracy: 0.6925 - val_loss: 0.7191
# Epoch 269/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7466 - loss: 0.6058 - val_accuracy: 0.7000 - val_loss: 0.7219
# Epoch 270/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7638 - loss: 0.5865 - val_accuracy: 0.6925 - val_loss: 0.7210
# Epoch 271/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7503 - loss: 0.6022 - val_accuracy: 0.6963 - val_loss: 0.7220
# Epoch 272/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7519 - loss: 0.6119 - val_accuracy: 0.6975 - val_loss: 0.7189
# Epoch 273/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7481 - loss: 0.5999 - val_accuracy: 0.7013 - val_loss: 0.7206
# Epoch 274/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7487 - loss: 0.6001 - val_accuracy: 0.7013 - val_loss: 0.7240
# Epoch 275/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7497 - loss: 0.6074 - val_accuracy: 0.6950 - val_loss: 0.7223
# Epoch 276/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7541 - loss: 0.5993 - val_accuracy: 0.6938 - val_loss: 0.7217
# Epoch 277/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7462 - loss: 0.6027 - val_accuracy: 0.6975 - val_loss: 0.7229
# Epoch 278/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7547 - loss: 0.5961 - val_accuracy: 0.6975 - val_loss: 0.7217
# Epoch 279/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7469 - loss: 0.6033 - val_accuracy: 0.6963 - val_loss: 0.7254
# Epoch 280/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7541 - loss: 0.5969 - val_accuracy: 0.6950 - val_loss: 0.7236
# Epoch 281/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7500 - loss: 0.6020 - val_accuracy: 0.6888 - val_loss: 0.7196
# Epoch 282/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7563 - loss: 0.5896 - val_accuracy: 0.6925 - val_loss: 0.7224
# Epoch 283/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7556 - loss: 0.5963 - val_accuracy: 0.6938 - val_loss: 0.7260
# Epoch 284/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7550 - loss: 0.5945 - val_accuracy: 0.6938 - val_loss: 0.7229
# Epoch 285/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7509 - loss: 0.6001 - val_accuracy: 0.6950 - val_loss: 0.7217
# Epoch 286/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7566 - loss: 0.5884 - val_accuracy: 0.6950 - val_loss: 0.7237
# Epoch 287/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7553 - loss: 0.5978 - val_accuracy: 0.6988 - val_loss: 0.7230
# Epoch 288/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7531 - loss: 0.5943 - val_accuracy: 0.6963 - val_loss: 0.7268
# Epoch 289/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7588 - loss: 0.5938 - val_accuracy: 0.6975 - val_loss: 0.7247
# Epoch 290/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7528 - loss: 0.5889 - val_accuracy: 0.6988 - val_loss: 0.7261
# Epoch 291/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7531 - loss: 0.5993 - val_accuracy: 0.6975 - val_loss: 0.7232
# Epoch 292/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7497 - loss: 0.5995 - val_accuracy: 0.6925 - val_loss: 0.7238
# Epoch 293/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7569 - loss: 0.5905 - val_accuracy: 0.6988 - val_loss: 0.7221
# Epoch 294/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7513 - loss: 0.5939 - val_accuracy: 0.6975 - val_loss: 0.7230
# Epoch 295/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7569 - loss: 0.5946 - val_accuracy: 0.6963 - val_loss: 0.7265
# Epoch 296/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7441 - loss: 0.5950 - val_accuracy: 0.6950 - val_loss: 0.7260
# Epoch 297/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7484 - loss: 0.5950 - val_accuracy: 0.7000 - val_loss: 0.7239
# Epoch 298/300
# 16/16 - 0s - 8ms/step - accuracy: 0.7656 - loss: 0.5826 - val_accuracy: 0.6950 - val_loss: 0.7263
# Epoch 299/300
# 16/16 - 0s - 7ms/step - accuracy: 0.7600 - loss: 0.5845 - val_accuracy: 0.7038 - val_loss: 0.7284
# Epoch 300/300
# 16/16 - 0s - 9ms/step - accuracy: 0.7625 - loss: 0.5906 - val_accuracy: 0.6950 - val_loss: 0.7226
# end of fit

# %%
def Show_history(fit): ## PLOTS THE FINAL WEIGHTS THROUGH VALIDATION AND TRAINING
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

## FOR LARGE EPOCHS, THE VALIDITION LOSS STARTS GOING UP -> OVERFITTING -> SOLUTION: EARLY STOPPING
## DID WE NEED ALL THOSE WEIGHTS AND FILTERS? OR WE COULD HAVE USED LESS? OR LESS LENGTH FOR THE WEIGHTS VECTORS?

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["Class 0","Class 1","Class 2"]

def show_confusion_matrix(validations, predictions, label="Model",perc=False):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    M = matrix
    f = 'd'
    cmap="GnBu"
    if perc:
        M=M/np.sum(M)
        f='.2%'
        cmap='Blues'
    seaborn.heatmap(M,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt=f,
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = np.array(model.predict(x_val))
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val,perc=True)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
model2 = keras.models.clone_model(model)

reg2 = keras.regularizers.l2(0.5)
model2.layers[0].kernel_regularizer = reg2
model2.layers[1].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2

opt = tf.keras.optimizers.legacy.Adam()
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 300

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 10
#       7 model2.layers[1].kernel_regularizer = reg2
#       8 model2.layers[2].kernel_regularizer = reg2
# ---> 10 opt = tf.keras.optimizers.legacy.Adam()
#      11 model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
#      13 BATCH_SIZE2 = 200
#
# File ~/anaconda3/envs/lcpB/lib/python3.12/site-packages/keras/src/optimizers/__init__.py:115, in LegacyOptimizerWarning.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args, **kwargs):
# --> 115     raise ImportError(
#     116         "`keras.optimizers.legacy` is not supported in Keras 3. When using "
#     117         "`tf.keras`, to continue using a `tf.keras.optimizers.legacy` "
#     118         "optimizer, you can install the `tf_keras` package (Keras 2) and "
#     119         "set the environment variable `TF_USE_LEGACY_KERAS=True` to "
#     120         "configure TensorFlow to use `tf_keras` when accessing `tf.keras`."
#     121     )
#
# ImportError: `keras.optimizers.legacy` is not supported in Keras 3. When using `tf.keras`, to continue using a `tf.keras.optimizers.legacy` optimizer, you can install the `tf_keras` package (Keras 2) and set the environment variable `TF_USE_LEGACY_KERAS=True` to configure TensorFlow to use `tf_keras` when accessing `tf.keras`.

# %%
Show_history(fit)
Show_history(fit2)

Show_weights(model,0,label="model1")
Show_weights(model2,0,label="model2")
Show_weights(model,2,label="model1")
Show_weights(model2,2,label="model2")


y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val, label="Model 1")
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 Show_history(fit)
# ----> 2 Show_history(fit2)
#       4 Show_weights(model,0,label="model1")
#       5 Show_weights(model2,0,label="model2")
#
# NameError: name 'fit2' is not defined
